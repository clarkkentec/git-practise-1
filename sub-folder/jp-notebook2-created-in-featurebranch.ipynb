# %%
#importing packages
import pandas as pd
print("Hello Git!!")
# Out:
# Hello Git!!

# %%
data = [1, 2, 3, 4, 5]
print(f"Total: {sum(data)}")
# Out:
# Total 15

# %%
for x in data:
    y = x * 2
    print(y)
# Out:
# 2
# 4
# 6
# 8
# 10
